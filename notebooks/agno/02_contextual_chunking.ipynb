# %% [markdown]
# # Enhanced Contextual Semantic Chunking Demo
#
# **Best of both worlds:**
# 1. Semantic chunking (natural boundaries)
# 2. LLM contextual enhancement (situating context)
# 3. Hybrid search (vector + FTS)
#
# **Best for**: Production systems, 20-30% better retrieval accuracy

# %% [markdown]
# ## Setup

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))
pdf_dir = project_root / "data" / "pdfs"

print(f"✅ Project root: {project_root}")
# Out:
# ✅ Project root: /home/vitor/contextual-rag-agno-supabase

# %% [markdown]
# ## 1. Download Sample PDFs

# %%
# import subprocess

# if pdf_dir.exists() and list(pdf_dir.glob("*.pdf")):
#     print(f"✅ PDFs already downloaded: {len(list(pdf_dir.glob('*.pdf')))} files")
# else:
#     print("📥 Downloading sample PDFs...")
#     result = subprocess.run([sys.executable, str(project_root / "scripts" / "download_pdfs.py")], 
#                           capture_output=True, text=True, cwd=str(project_root))
#     print(result.stdout)

# %% [markdown]
# ## 2. Initialize Enhanced Knowledge Base

# %%
from src.storage.contextual_agno_knowledge import ContextualAgnoKnowledge

kb = ContextualAgnoKnowledge(table_name="economics_enhanced_gemini")
print("✅ Enhanced knowledge base initialized")
print("   - Semantic chunking: ON")
print("   - Contextual enhancement: ON")
print("   - Hybrid search: ON")
print(f"   - Table: {kb.knowledge.vector_db.table_name}")
# Out:
# ✅ Enhanced knowledge base initialized
#    - Semantic chunking: ON
#    - Contextual enhancement: ON
#    - Hybrid search: ON
#    - Table: economics_enhanced_gemini

# %% [markdown]
# ## 3. Ingest PDF with Context Enhancement
#
# This will:
# 1. Extract text from PDF
# 2. Chunk semantically (natural boundaries)
# 3. Add LLM-generated context to each chunk
# 4. Store with hybrid indexing

# %%
# # pdf_path = pdf_dir / "The Richest Man In Babylon.pdf"
# # kb.ingest_pdf(str(pdf_path))
# # print("\n✅ PDF ingested with contextual enhancement")

# kb.ingest_directory(str(pdf_dir))
# print("✅ All PDFs ingested")
# Out:
# 📚 Ingesting directory with context-enhanced semantic chunking: /home/vitor/contextual-rag-agno-supabase/data/pdfs
# INFO Adding content from path, 6cdcf639-e8d3-54a0-9c63-ece7291a494f, None,
#      /home/vitor/contextual-rag-agno-supabase/data/pdfs, None
# INFO Adding content from path, bd502884-17e2-56a6-b869-8298c0c2afa8, None,
#      /home/vitor/contextual-rag-agno-supabase/data/pdfs/TheIntelligentInvestor.pdf, None
# Warning: Context generation failed: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# INFO Processing batch starting at index 0, size: 100
# INFO Upserted batch of 100 documents.
# INFO Processing batch starting at index 100, size: 100
# INFO Upserted batch of 100 documents.
# INFO Processing batch starting at index 200, size: 100
# INFO Upserted batch of 100 documents.
# INFO Processing batch starting at index 300, size: 100
# INFO Upserted batch of 100 documents.
# INFO Processing batch starting at index 400, size: 100
# ERROR    Error with batch starting at index 400: (psycopg.errors.DuplicatePreparedStatement) prepared statement
#          "_pg3_0" already exists
#          [SQL: INSERT INTO ai.economics_enhanced_gemini (id, name, meta_data, filters, content, embedding, usage,
#          content_hash, content_id) VALUES (%(id_m0)s::VARCHAR, %(name_m0)s::VARCHAR, %(meta_data_m0)s::JSONB,
#          %(filters_m0)s::JSONB, %(content_m0)s::VARCHAR, %(embedding_m0)s, %(usage_m0)s::JSONB,
#          %(content_hash_m0)s::VARCHAR, %(content_id_m0)s::VARCHAR), (%(id_m1)s::VARCHAR, %(name_m1)s::VARCHAR,
#          %(meta_data_m1)s::JSONB, %(filters_m1)s::JSONB, %(content_m1)s::VARCHAR, %(embedding_m1)s,
#          %(usage_m1)s::JSONB, %(content_hash_m1)s::VARCHAR, %(content_id_m1)s::VARCHAR), (%(id_m2)s::VARCHAR,
#          %(name_m2)s::VARCHAR, %(meta_data_m2)s::JSONB, %(filters_m2)s::JSONB, %(content_m2)s::VARCHAR,
#          %(embedding_m2)s, %(usage_m2)s::JSONB, %(content_hash_m2)s::VARCHAR, %(content_id_m2)s::VARCHAR),
#          (%(id_m3)s::VARCHAR, %(name_m3)s::VARCHAR, %(meta_data_m3)s::JSONB, %(filters_m3)s::JSONB,
#          %(content_m3)s::VARCHAR, %(embedding_m3)s, %(usage_m3)s::JSONB, %(content_hash_m3)s::VARCHAR,
#          %(content_id_m3)s::VARCHAR), (%(id_m4)s::VARCHAR, %(name_m4)s::VARCHAR, %(meta_data_m4)s::JSONB,
#          %(filters_m4)s::JSONB, %(content_m4)s::VARCHAR, %(embedding_m4)s, %(usage_m4)s::JSONB,
#          %(content_hash_m4)s::VARCHAR, %(content_id_m4)s::VARCHAR), (%(id_m5)s::VARCHAR, %(name_m5)s::VARCHAR,
#          %(meta_data_m5)s::JSONB, %(filters_m5)s::JSONB, %(content_m5)s::VARCHAR, %(embedding_m5)s,
#          %(usage_m5)s::JSONB, %(content_hash_m5)s::VARCHAR, %(content_id_m5)s::VARCHAR), (%(id_m6)s::VARCHAR,
#          %(name_m6)s::VARCHAR, %(meta_data_m6)s::JSONB, %(filters_m6)s::JSONB, %(content_m6)s::VARCHAR,
#          %(embedding_m6)s, %(usage_m6)s::JSONB, %(content_hash_m6)s::VARCHAR, %(content_id_m6)s::VARCHAR),
#          (%(id_m7)s::VARCHAR, %(name_m7)s::VARCHAR, %(meta_data_m7)s::JSONB, %(filters_m7)s::JSONB,
#          %(content_m7)s::VARCHAR, %(embedding_m7)s, %(usage_m7)s::JSONB, %(content_hash_m7)s::VARCHAR,
#          %(content_id_m7)s::VARCHAR), (%(id_m8)s::VARCHAR, %(name_m8)s::VARCHAR, %(meta_data_m8)s::JSONB,
#          %(filters_m8)s::JSONB, %(content_m8)s::VARCHAR, %(embedding_m8)s, %(usage_m8)s::JSONB,
#          %(content_hash_m8)s::VARCHAR, %(content_id_m8)s::VARCHAR), (%(id_m9)s::VARCHAR, %(name_m9)s::VARCHAR,
#          %(meta_data_m9)s::JSONB, %(filters_m9)s::JSONB, %(content_m9)s::VARCHAR, %(embedding_m9)s,
#          %(usage_m9)s::JSONB, %(content_hash_m9)s::VARCHAR, %(content_id_m9)s::VARCHAR), (%(id_m10)s::VARCHAR,
#          %(name_m10)s::VARCHAR, %(meta_data_m10)s::JSONB, %(filters_m10)s::JSONB, %(content_m10)s::VARCHAR,
#          %(embedding_m10)s, %(usage_m10)s::JSONB, %(content_hash_m10)s::VARCHAR, %(content_id_m10)s::VARCHAR),
#          (%(id_m11)s::VARCHAR, %(name_m11)s::VARCHAR, %(meta_data_m11)s::JSONB, %(filters_m11)s::JSONB,
#          %(content_m11)s::VARCHAR, %(embedding_m11)s, %(usage_m11)s::JSONB, %(content_hash_m11)s::VARCHAR,
#          %(content_id_m11)s::VARCHAR), (%(id_m12)s::VARCHAR, %(name_m12)s::VARCHAR, %(meta_data_m12)s::JSONB,
#          %(filters_m12)s::JSONB, %(content_m12)s::VARCHAR, %(embedding_m12)s, %(usage_m12)s::JSONB,
#          %(content_hash_m12)s::VARCHAR, %(content_id_m12)s::VARCHAR), (%(id_m13)s::VARCHAR, %(name_m13)s::VARCHAR,
#          %(meta_data_m13)s::JSONB, %(filters_m13)s::JSONB, %(content_m13)s::VARCHAR, %(embedding_m13)s,
#          %(usage_m13)s::JSONB, %(content_hash_m13)s::VARCHAR, %(content_id_m13)s::VARCHAR), (%(id_m14)s::VARCHAR,
#          %(name_m14)s::VARCHAR, %(meta_data_m14)s::JSONB, %(filters_m14)s::JSONB, %(content_m14)s::VARCHAR,
#          %(embedding_m14)s, %(usage_m14)s::JSONB, %(content_hash_m14)s::VARCHAR, %(content_id_m14)s::VARCHAR),
#          (%(id_m15)s::VARCHAR, %(name_m15)s::VARCHAR, %(meta_data_m15)s::JSONB, %(filters_m15)s::JSONB,
#          %(content_m15)s::VARCHAR, %(embedding_m15)s, %(usage_m15)s::JSONB, %(content_hash_m15)s::VARCHAR,
#          %(content_id_m15)s::VARCHAR), (%(id_m16)s::VARCHAR, %(name_m16)s::VARCHAR, %(meta_data_m16)s::JSONB,
#          %(filters_m16)s::JSONB, %(content_m16)s::VARCHAR, %(embedding_m16)s, %(usage_m16)s::JSONB,
#          %(content_hash_m16)s::VARCHAR, %(content_id_m16)s::VARCHAR), (%(id_m17)s::VARCHAR, %(name_m17)s::VARCHAR,
#          %(meta_data_m17)s::JSONB, %(filters_m17)s::JSONB, %(content_m17)s::VARCHAR, %(embedding_m17)s,
#          %(usage_m17)s::JSONB, %(content_hash_m17)s::VARCHAR, %(content_id_m17)s::VARCHAR), (%(id_m18)s::VARCHAR,
#          %(name_m18)s::VARCHAR, %(meta_data_m18)s::JSONB, %(filters_m18)s::JSONB, %(content_m18)s::VARCHAR,
#          %(embedding_m18)s, %(usage_m18)s::JSONB, %(content_hash_m18)s::VARCHAR, %(content_id_m18)s::VARCHAR),
#          (%(id_m19)s::VARCHAR, %(name_m19)s::VARCHAR, %(meta_data_m19)s::JSONB, %(filters_m19)s::JSONB,
#          %(content_m19)s::VARCHAR, %(embedding_m19)s, %(usage_m19)s::JSONB, %(content_hash_m19)s::VARCHAR,
#          %(content_id_m19)s::VARCHAR), (%(id_m20)s::VARCHAR, %(name_m20)s::VARCHAR, %(meta_data_m20)s::JSONB,
#          %(filters_m20)s::JSONB, %(content_m20)s::VARCHAR, %(embedding_m20)s, %(usage_m20)s::JSONB,
#          %(content_hash_m20)s::VARCHAR, %(content_id_m20)s::VARCHAR), (%(id_m21)s::VARCHAR, %(name_m21)s::VARCHAR,
#          %(meta_data_m21)s::JSONB, %(filters_m21)s::JSONB, %(content_m21)s::VARCHAR, %(embedding_m21)s,
#          %(usage_m21)s::JSONB, %(content_hash_m21)s::VARCHAR, %(content_id_m21)s::VARCHAR), (%(id_m22)s::VARCHAR,
#          %(name_m22)s::VARCHAR, %(meta_data_m22)s::JSONB, %(filters_m22)s::JSONB, %(content_m22)s::VARCHAR,
#          %(embedding_m22)s, %(usage_m22)s::JSONB, %(content_hash_m22)s::VARCHAR, %(content_id_m22)s::VARCHAR),
#          (%(id_m23)s::VARCHAR, %(name_m23)s::VARCHAR, %(meta_data_m23)s::JSONB, %(filters_m23)s::JSONB,
#          %(content_m23)s::VARCHAR, %(embedding_m23)s, %(usage_m23)s::JSONB, %(content_hash_m23)s::VARCHAR,
#          %(content_id_m23)s::VARCHAR), (%(id_m24)s::VARCHAR, %(name_m24)s::VARCHAR, %(meta_data_m24)s::JSONB,
#          %(filters_m24)s::JSONB, %(content_m24)s::VARCHAR, %(embedding_m24)s, %(usage_m24)s::JSONB,
#          %(content_hash_m24)s::VARCHAR, %(content_id_m24)s::VARCHAR), (%(id_m25)s::VARCHAR, %(name_m25)s::VARCHAR,
#          %(meta_data_m25)s::JSONB, %(filters_m25)s::JSONB, %(content_m25)s::VARCHAR, %(embedding_m25)s,
#          %(usage_m25)s::JSONB, %(content_hash_m25)s::VARCHAR, %(content_id_m25)s::VARCHAR), (%(id_m26)s::VARCHAR,
#          %(name_m26)s::VARCHAR, %(meta_data_m26)s::JSONB, %(filters_m26)s::JSONB, %(content_m26)s::VARCHAR,
#          %(embedding_m26)s, %(usage_m26)s::JSONB, %(content_hash_m26)s::VARCHAR, %(content_id_m26)s::VARCHAR),
#          (%(id_m27)s::VARCHAR, %(name_m27)s::VARCHAR, %(meta_data_m27)s::JSONB, %(filters_m27)s::JSONB,
#          %(content_m27)s::VARCHAR, %(embedding_m27)s, %(usage_m27)s::JSONB, %(content_hash_m27)s::VARCHAR,
#          %(content_id_m27)s::VARCHAR), (%(id_m28)s::VARCHAR, %(name_m28)s::VARCHAR, %(meta_data_m28)s::JSONB,
#          %(filters_m28)s::JSONB, %(content_m28)s::VARCHAR, %(embedding_m28)s, %(usage_m28)s::JSONB,
#          %(content_hash_m28)s::VARCHAR, %(content_id_m28)s::VARCHAR), (%(id_m29)s::VARCHAR, %(name_m29)s::VARCHAR,
#          %(meta_data_m29)s::JSONB, %(filters_m29)s::JSONB, %(content_m29)s::VARCHAR, %(embedding_m29)s,
#          %(usage_m29)s::JSONB, %(content_hash_m29)s::VARCHAR, %(content_id_m29)s::VARCHAR), (%(id_m30)s::VARCHAR,
#          %(name_m30)s::VARCHAR, %(meta_data_m30)s::JSONB, %(filters_m30)s::JSONB, %(content_m30)s::VARCHAR,
#          %(embedding_m30)s, %(usage_m30)s::JSONB, %(content_hash_m30)s::VARCHAR, %(content_id_m30)s::VARCHAR),
#          (%(id_m31)s::VARCHAR, %(name_m31)s::VARCHAR, %(meta_data_m31)s::JSONB, %(filters_m31)s::JSONB,
#          %(content_m31)s::VARCHAR, %(embedding_m31)s, %(usage_m31)s::JSONB, %(content_hash_m31)s::VARCHAR,
#          %(content_id_m31)s::VARCHAR), (%(id_m32)s::VARCHAR, %(name_m32)s::VARCHAR, %(meta_data_m32)s::JSONB,
#          %(filters_m32)s::JSONB, %(content_m32)s::VARCHAR, %(embedding_m32)s, %(usage_m32)s::JSONB,
#          %(content_hash_m32)s::VARCHAR, %(content_id_m32)s::VARCHAR), (%(id_m33)s::VARCHAR, %(name_m33)s::VARCHAR,
#          %(meta_data_m33)s::JSONB, %(filters_m33)s::JSONB, %(content_m33)s::VARCHAR, %(embedding_m33)s,
#          %(usage_m33)s::JSONB, %(content_hash_m33)s::VARCHAR, %(content_id_m33)s::VARCHAR), (%(id_m34)s::VARCHAR,
#          %(name_m34)s::VARCHAR, %(meta_data_m34)s::JSONB, %(filters_m34)s::JSONB, %(content_m34)s::VARCHAR,
#          %(embedding_m34)s, %(usage_m34)s::JSONB, %(content_hash_m34)s::VARCHAR, %(content_id_m34)s::VARCHAR),
#          (%(id_m35)s::VARCHAR, %(name_m35)s::VARCHAR, %(meta_data_m35)s::JSONB, %(filters_m35)s::JSONB,
#          %(content_m35)s::VARCHAR, %(embedding_m35)s, %(usage_m35)s::JSONB, %(content_hash_m35)s::VARCHAR,
#          %(content_id_m35)s::VARCHAR), (%(id_m36)s::VARCHAR, %(name_m36)s::VARCHAR, %(meta_data_m36)s::JSONB,
#          %(filters_m36)s::JSONB, %(content_m36)s::VARCHAR, %(embedding_m36)s, %(usage_m36)s::JSONB,
#          %(content_hash_m36)s::VARCHAR, %(content_id_m36)s::VARCHAR), (%(id_m37)s::VARCHAR, %(name_m37)s::VARCHAR,
#          %(meta_data_m37)s::JSONB, %(filters_m37)s::JSONB, %(content_m37)s::VARCHAR, %(embedding_m37)s,
#          %(usage_m37)s::JSONB, %(content_hash_m37)s::VARCHAR, %(content_id_m37)s::VARCHAR), (%(id_m38)s::VARCHAR,
#          %(name_m38)s::VARCHAR, %(meta_data_m38)s::JSONB, %(filters_m38)s::JSONB, %(content_m38)s::VARCHAR,
#          %(embedding_m38)s, %(usage_m38)s::JSONB, %(content_hash_m38)s::VARCHAR, %(content_id_m38)s::VARCHAR),
#          (%(id_m39)s::VARCHAR, %(name_m39)s::VARCHAR, %(meta_data_m39)s::JSONB, %(filters_m39)s::JSONB,
#          %(content_m39)s::VARCHAR, %(embedding_m39)s, %(usage_m39)s::JSONB, %(content_hash_m39)s::VARCHAR,
#          %(content_id_m39)s::VARCHAR), (%(id_m40)s::VARCHAR, %(name_m40)s::VARCHAR, %(meta_data_m40)s::JSONB,
#          %(filters_m40)s::JSONB, %(content_m40)s::VARCHAR, %(embedding_m40)s, %(usage_m40)s::JSONB,
#          %(content_hash_m40)s::VARCHAR, %(content_id_m40)s::VARCHAR), (%(id_m41)s::VARCHAR, %(name_m41)s::VARCHAR,
#          %(meta_data_m41)s::JSONB, %(filters_m41)s::JSONB, %(content_m41)s::VARCHAR, %(embedding_m41)s,
#          %(usage_m41)s::JSONB, %(content_hash_m41)s::VARCHAR, %(content_id_m41)s::VARCHAR), (%(id_m42)s::VARCHAR,
#          %(name_m42)s::VARCHAR, %(meta_data_m42)s::JSONB, %(filters_m42)s::JSONB, %(content_m42)s::VARCHAR,
#          %(embedding_m42)s, %(usage_m42)s::JSONB, %(content_hash_m42)s::VARCHAR, %(content_id_m42)s::VARCHAR),
#          (%(id_m43)s::VARCHAR, %(name_m43)s::VARCHAR, %(meta_data_m43)s::JSONB, %(filters_m43)s::JSONB,
#          %(content_m43)s::VARCHAR, %(embedding_m43)s, %(usage_m43)s::JSONB, %(content_hash_m43)s::VARCHAR,
#          %(content_id_m43)s::VARCHAR), (%(id_m44)s::VARCHAR, %(name_m44)s::VARCHAR, %(meta_data_m44)s::JSONB,
#          %(filters_m44)s::JSONB, %(content_m44)s::VARCHAR, %(embedding_m44)s, %(usage_m44)s::JSONB,
#          %(content_hash_m44)s::VARCHAR, %(content_id_m44)s::VARCHAR), (%(id_m45)s::VARCHAR, %(name_m45)s::VARCHAR,
#          %(meta_data_m45)s::JSONB, %(filters_m45)s::JSONB, %(content_m45)s::VARCHAR, %(embedding_m45)s,
#          %(usage_m45)s::JSONB, %(content_hash_m45)s::VARCHAR, %(content_id_m45)s::VARCHAR), (%(id_m46)s::VARCHAR,
#          %(name_m46)s::VARCHAR, %(meta_data_m46)s::JSONB, %(filters_m46)s::JSONB, %(content_m46)s::VARCHAR,
#          %(embedding_m46)s, %(usage_m46)s::JSONB, %(content_hash_m46)s::VARCHAR, %(content_id_m46)s::VARCHAR),
#          (%(id_m47)s::VARCHAR, %(name_m47)s::VARCHAR, %(meta_data_m47)s::JSONB, %(filters_m47)s::JSONB,
#          %(content_m47)s::VARCHAR, %(embedding_m47)s, %(usage_m47)s::JSONB, %(content_hash_m47)s::VARCHAR,
#          %(content_id_m47)s::VARCHAR), (%(id_m48)s::VARCHAR, %(name_m48)s::VARCHAR, %(meta_data_m48)s::JSONB,
#          %(filters_m48)s::JSONB, %(content_m48)s::VARCHAR, %(embedding_m48)s, %(usage_m48)s::JSONB,
#          %(content_hash_m48)s::VARCHAR, %(content_id_m48)s::VARCHAR), (%(id_m49)s::VARCHAR, %(name_m49)s::VARCHAR,
#          %(meta_data_m49)s::JSONB, %(filters_m49)s::JSONB, %(content_m49)s::VARCHAR, %(embedding_m49)s,
#          %(usage_m49)s::JSONB, %(content_hash_m49)s::VARCHAR, %(content_id_m49)s::VARCHAR), (%(id_m50)s::VARCHAR,
#          %(name_m50)s::VARCHAR, %(meta_data_m50)s::JSONB, %(filters_m50)s::JSONB, %(content_m50)s::VARCHAR,
#          %(embedding_m50)s, %(usage_m50)s::JSONB, %(content_hash_m50)s::VARCHAR, %(content_id_m50)s::VARCHAR),
#          (%(id_m51)s::VARCHAR, %(name_m51)s::VARCHAR, %(meta_data_m51)s::JSONB, %(filters_m51)s::JSONB,
#          %(content_m51)s::VARCHAR, %(embedding_m51)s, %(usage_m51)s::JSONB, %(content_hash_m51)s::VARCHAR,
#          %(content_id_m51)s::VARCHAR), (%(id_m52)s::VARCHAR, %(name_m52)s::VARCHAR, %(meta_data_m52)s::JSONB,
#          %(filters_m52)s::JSONB, %(content_m52)s::VARCHAR, %(embedding_m52)s, %(usage_m52)s::JSONB,
#          %(content_hash_m52)s::VARCHAR, %(content_id_m52)s::VARCHAR), (%(id_m53)s::VARCHAR, %(name_m53)s::VARCHAR,
#          %(meta_data_m53)s::JSONB, %(filters_m53)s::JSONB, %(content_m53)s::VARCHAR, %(embedding_m53)s,
#          %(usage_m53)s::JSONB, %(content_hash_m53)s::VARCHAR, %(content_id_m53)s::VARCHAR), (%(id_m54)s::VARCHAR,
#          %(name_m54)s::VARCHAR, %(meta_data_m54)s::JSONB, %(filters_m54)s::JSONB, %(content_m54)s::VARCHAR,
#          %(embedding_m54)s, %(usage_m54)s::JSONB, %(content_hash_m54)s::VARCHAR, %(content_id_m54)s::VARCHAR),
#          (%(id_m55)s::VARCHAR, %(name_m55)s::VARCHAR, %(meta_data_m55)s::JSONB, %(filters_m55)s::JSONB,
#          %(content_m55)s::VARCHAR, %(embedding_m55)s, %(usage_m55)s::JSONB, %(content_hash_m55)s::VARCHAR,
#          %(content_id_m55)s::VARCHAR), (%(id_m56)s::VARCHAR, %(name_m56)s::VARCHAR, %(meta_data_m56)s::JSONB,
#          %(filters_m56)s::JSONB, %(content_m56)s::VARCHAR, %(embedding_m56)s, %(usage_m56)s::JSONB,
#          %(content_hash_m56)s::VARCHAR, %(content_id_m56)s::VARCHAR), (%(id_m57)s::VARCHAR, %(name_m57)s::VARCHAR,
#          %(meta_data_m57)s::JSONB, %(filters_m57)s::JSONB, %(content_m57)s::VARCHAR, %(embedding_m57)s,
#          %(usage_m57)s::JSONB, %(content_hash_m57)s::VARCHAR, %(content_id_m57)s::VARCHAR), (%(id_m58)s::VARCHAR,
#          %(name_m58)s::VARCHAR, %(meta_data_m58)s::JSONB, %(filters_m58)s::JSONB, %(content_m58)s::VARCHAR,
#          %(embedding_m58)s, %(usage_m58)s::JSONB, %(content_hash_m58)s::VARCHAR, %(content_id_m58)s::VARCHAR),
#          (%(id_m59)s::VARCHAR, %(name_m59)s::VARCHAR, %(meta_data_m59)s::JSONB, %(filters_m59)s::JSONB,
#          %(content_m59)s::VARCHAR, %(embedding_m59)s, %(usage_m59)s::JSONB, %(content_hash_m59)s::VARCHAR,
#          %(content_id_m59)s::VARCHAR), (%(id_m60)s::VARCHAR, %(name_m60)s::VARCHAR, %(meta_data_m60)s::JSONB,
#          %(filters_m60)s::JSONB, %(content_m60)s::VARCHAR, %(embedding_m60)s, %(usage_m60)s::JSONB,
#          %(content_hash_m60)s::VARCHAR, %(content_id_m60)s::VARCHAR), (%(id_m61)s::VARCHAR, %(name_m61)s::VARCHAR,
#          %(meta_data_m61)s::JSONB, %(filters_m61)s::JSONB, %(content_m61)s::VARCHAR, %(embedding_m61)s,
#          %(usage_m61)s::JSONB, %(content_hash_m61)s::VARCHAR, %(content_id_m61)s::VARCHAR), (%(id_m62)s::VARCHAR,
#          %(name_m62)s::VARCHAR, %(meta_data_m62)s::JSONB, %(filters_m62)s::JSONB, %(content_m62)s::VARCHAR,
#          %(embedding_m62)s, %(usage_m62)s::JSONB, %(content_hash_m62)s::VARCHAR, %(content_id_m62)s::VARCHAR),
#          (%(id_m63)s::VARCHAR, %(name_m63)s::VARCHAR, %(meta_data_m63)s::JSONB, %(filters_m63)s::JSONB,
#          %(content_m63)s::VARCHAR, %(embedding_m63)s, %(usage_m63)s::JSONB, %(content_hash_m63)s::VARCHAR,
#          %(content_id_m63)s::VARCHAR), (%(id_m64)s::VARCHAR, %(name_m64)s::VARCHAR, %(meta_data_m64)s::JSONB,
#          %(filters_m64)s::JSONB, %(content_m64)s::VARCHAR, %(embedding_m64)s, %(usage_m64)s::JSONB,
#          %(content_hash_m64)s::VARCHAR, %(content_id_m64)s::VARCHAR), (%(id_m65)s::VARCHAR, %(name_m65)s::VARCHAR,
#          %(meta_data_m65)s::JSONB, %(filters_m65)s::JSONB, %(content_m65)s::VARCHAR, %(embedding_m65)s,
#          %(usage_m65)s::JSONB, %(content_hash_m65)s::VARCHAR, %(content_id_m65)s::VARCHAR), (%(id_m66)s::VARCHAR,
#          %(name_m66)s::VARCHAR, %(meta_data_m66)s::JSONB, %(filters_m66)s::JSONB, %(content_m66)s::VARCHAR,
#          %(embedding_m66)s, %(usage_m66)s::JSONB, %(content_hash_m66)s::VARCHAR, %(content_id_m66)s::VARCHAR),
#          (%(id_m67)s::VARCHAR, %(name_m67)s::VARCHAR, %(meta_data_m67)s::JSONB, %(filters_m67)s::JSONB,
#          %(content_m67)s::VARCHAR, %(embedding_m67)s, %(usage_m67)s::JSONB, %(content_hash_m67)s::VARCHAR,
#          %(content_id_m67)s::VARCHAR), (%(id_m68)s::VARCHAR, %(name_m68)s::VARCHAR, %(meta_data_m68)s::JSONB,
#          %(filters_m68)s::JSONB, %(content_m68)s::VARCHAR, %(embedding_m68)s, %(usage_m68)s::JSONB,
#          %(content_hash_m68)s::VARCHAR, %(content_id_m68)s::VARCHAR), (%(id_m69)s::VARCHAR, %(name_m69)s::VARCHAR,
#          %(meta_data_m69)s::JSONB, %(filters_m69)s::JSONB, %(content_m69)s::VARCHAR, %(embedding_m69)s,
#          %(usage_m69)s::JSONB, %(content_hash_m69)s::VARCHAR, %(content_id_m69)s::VARCHAR), (%(id_m70)s::VARCHAR,
#          %(name_m70)s::VARCHAR, %(meta_data_m70)s::JSONB, %(filters_m70)s::JSONB, %(content_m70)s::VARCHAR,
#          %(embedding_m70)s, %(usage_m70)s::JSONB, %(content_hash_m70)s::VARCHAR, %(content_id_m70)s::VARCHAR),
#          (%(id_m71)s::VARCHAR, %(name_m71)s::VARCHAR, %(meta_data_m71)s::JSONB, %(filters_m71)s::JSONB,
#          %(content_m71)s::VARCHAR, %(embedding_m71)s, %(usage_m71)s::JSONB, %(content_hash_m71)s::VARCHAR,
#          %(content_id_m71)s::VARCHAR), (%(id_m72)s::VARCHAR, %(name_m72)s::VARCHAR, %(meta_data_m72)s::JSONB,
#          %(filters_m72)s::JSONB, %(content_m72)s::VARCHAR, %(embedding_m72)s, %(usage_m72)s::JSONB,
#          %(content_hash_m72)s::VARCHAR, %(content_id_m72)s::VARCHAR), (%(id_m73)s::VARCHAR, %(name_m73)s::VARCHAR,
#          %(meta_data_m73)s::JSONB, %(filters_m73)s::JSONB, %(content_m73)s::VARCHAR, %(embedding_m73)s,
#          %(usage_m73)s::JSONB, %(content_hash_m73)s::VARCHAR, %(content_id_m73)s::VARCHAR), (%(id_m74)s::VARCHAR,
#          %(name_m74)s::VARCHAR, %(meta_data_m74)s::JSONB, %(filters_m74)s::JSONB, %(content_m74)s::VARCHAR,
#          %(embedding_m74)s, %(usage_m74)s::JSONB, %(content_hash_m74)s::VARCHAR, %(content_id_m74)s::VARCHAR),
#          (%(id_m75)s::VARCHAR, %(name_m75)s::VARCHAR, %(meta_data_m75)s::JSONB, %(filters_m75)s::JSONB,
#          %(content_m75)s::VARCHAR, %(embedding_m75)s, %(usage_m75)s::JSONB, %(content_hash_m75)s::VARCHAR,
#          %(content_id_m75)s::VARCHAR), (%(id_m76)s::VARCHAR, %(name_m76)s::VARCHAR, %(meta_data_m76)s::JSONB,
#          %(filters_m76)s::JSONB, %(content_m76)s::VARCHAR, %(embedding_m76)s, %(usage_m76)s::JSONB,
#          %(content_hash_m76)s::VARCHAR, %(content_id_m76)s::VARCHAR), (%(id_m77)s::VARCHAR, %(name_m77)s::VARCHAR,
#          %(meta_data_m77)s::JSONB, %(filters_m77)s::JSONB, %(content_m77)s::VARCHAR, %(embedding_m77)s,
#          %(usage_m77)s::JSONB, %(content_hash_m77)s::VARCHAR, %(content_id_m77)s::VARCHAR), (%(id_m78)s::VARCHAR,
#          %(name_m78)s::VARCHAR, %(meta_data_m78)s::JSONB, %(filters_m78)s::JSONB, %(content_m78)s::VARCHAR,
#          %(embedding_m78)s, %(usage_m78)s::JSONB, %(content_hash_m78)s::VARCHAR, %(content_id_m78)s::VARCHAR),
#          (%(id_m79)s::VARCHAR, %(name_m79)s::VARCHAR, %(meta_data_m79)s::JSONB, %(filters_m79)s::JSONB,
#          %(content_m79)s::VARCHAR, %(embedding_m79)s, %(usage_m79)s::JSONB, %(content_hash_m79)s::VARCHAR,
#          %(content_id_m79)s::VARCHAR), (%(id_m80)s::VARCHAR, %(name_m80)s::VARCHAR, %(meta_data_m80)s::JSONB,
#          %(filters_m80)s::JSONB, %(content_m80)s::VARCHAR, %(embedding_m80)s, %(usage_m80)s::JSONB,
#          %(content_hash_m80)s::VARCHAR, %(content_id_m80)s::VARCHAR), (%(id_m81)s::VARCHAR, %(name_m81)s::VARCHAR,
#          %(meta_data_m81)s::JSONB, %(filters_m81)s::JSONB, %(content_m81)s::VARCHAR, %(embedding_m81)s,
#          %(usage_m81)s::JSONB, %(content_hash_m81)s::VARCHAR, %(content_id_m81)s::VARCHAR), (%(id_m82)s::VARCHAR,
#          %(name_m82)s::VARCHAR, %(meta_data_m82)s::JSONB, %(filters_m82)s::JSONB, %(content_m82)s::VARCHAR,
#          %(embedding_m82)s, %(usage_m82)s::JSONB, %(content_hash_m82)s::VARCHAR, %(content_id_m82)s::VARCHAR),
#          (%(id_m83)s::VARCHAR, %(name_m83)s::VARCHAR, %(meta_data_m83)s::JSONB, %(filters_m83)s::JSONB,
#          %(content_m83)s::VARCHAR, %(embedding_m83)s, %(usage_m83)s::JSONB, %(content_hash_m83)s::VARCHAR,
#          %(content_id_m83)s::VARCHAR), (%(id_m84)s::VARCHAR, %(name_m84)s::VARCHAR, %(meta_data_m84)s::JSONB,
#          %(filters_m84)s::JSONB, %(content_m84)s::VARCHAR, %(embedding_m84)s, %(usage_m84)s::JSONB,
#          %(content_hash_m84)s::VARCHAR, %(content_id_m84)s::VARCHAR), (%(id_m85)s::VARCHAR, %(name_m85)s::VARCHAR,
#          %(meta_data_m85)s::JSONB, %(filters_m85)s::JSONB, %(content_m85)s::VARCHAR, %(embedding_m85)s,
#          %(usage_m85)s::JSONB, %(content_hash_m85)s::VARCHAR, %(content_id_m85)s::VARCHAR), (%(id_m86)s::VARCHAR,
#          %(name_m86)s::VARCHAR, %(meta_data_m86)s::JSONB, %(filters_m86)s::JSONB, %(content_m86)s::VARCHAR,
#          %(embedding_m86)s, %(usage_m86)s::JSONB, %(content_hash_m86)s::VARCHAR, %(content_id_m86)s::VARCHAR),
#          (%(id_m87)s::VARCHAR, %(name_m87)s::VARCHAR, %(meta_data_m87)s::JSONB, %(filters_m87)s::JSONB,
#          %(content_m87)s::VARCHAR, %(embedding_m87)s, %(usage_m87)s::JSONB, %(content_hash_m87)s::VARCHAR,
#          %(content_id_m87)s::VARCHAR), (%(id_m88)s::VARCHAR, %(name_m88)s::VARCHAR, %(meta_data_m88)s::JSONB,
#          %(filters_m88)s::JSONB, %(content_m88)s::VARCHAR, %(embedding_m88)s, %(usage_m88)s::JSONB,
#          %(content_hash_m88)s::VARCHAR, %(content_id_m88)s::VARCHAR), (%(id_m89)s::VARCHAR, %(name_m89)s::VARCHAR,
#          %(meta_data_m89)s::JSONB, %(filters_m89)s::JSONB, %(content_m89)s::VARCHAR, %(embedding_m89)s,
#          %(usage_m89)s::JSONB, %(content_hash_m89)s::VARCHAR, %(content_id_m89)s::VARCHAR), (%(id_m90)s::VARCHAR,
#          %(name_m90)s::VARCHAR, %(meta_data_m90)s::JSONB, %(filters_m90)s::JSONB, %(content_m90)s::VARCHAR,
#          %(embedding_m90)s, %(usage_m90)s::JSONB, %(content_hash_m90)s::VARCHAR, %(content_id_m90)s::VARCHAR),
#          (%(id_m91)s::VARCHAR, %(name_m91)s::VARCHAR, %(meta_data_m91)s::JSONB, %(filters_m91)s::JSONB,
#          %(content_m91)s::VARCHAR, %(embedding_m91)s, %(usage_m91)s::JSONB, %(content_hash_m91)s::VARCHAR,
#          %(content_id_m91)s::VARCHAR), (%(id_m92)s::VARCHAR, %(name_m92)s::VARCHAR, %(meta_data_m92)s::JSONB,
#          %(filters_m92)s::JSONB, %(content_m92)s::VARCHAR, %(embedding_m92)s, %(usage_m92)s::JSONB,
#          %(content_hash_m92)s::VARCHAR, %(content_id_m92)s::VARCHAR), (%(id_m93)s::VARCHAR, %(name_m93)s::VARCHAR,
#          %(meta_data_m93)s::JSONB, %(filters_m93)s::JSONB, %(content_m93)s::VARCHAR, %(embedding_m93)s,
#          %(usage_m93)s::JSONB, %(content_hash_m93)s::VARCHAR, %(content_id_m93)s::VARCHAR), (%(id_m94)s::VARCHAR,
#          %(name_m94)s::VARCHAR, %(meta_data_m94)s::JSONB, %(filters_m94)s::JSONB, %(content_m94)s::VARCHAR,
#          %(embedding_m94)s, %(usage_m94)s::JSONB, %(content_hash_m94)s::VARCHAR, %(content_id_m94)s::VARCHAR),
#          (%(id_m95)s::VARCHAR, %(name_m95)s::VARCHAR, %(meta_data_m95)s::JSONB, %(filters_m95)s::JSONB,
#          %(content_m95)s::VARCHAR, %(embedding_m95)s, %(usage_m95)s::JSONB, %(content_hash_m95)s::VARCHAR,
#          %(content_id_m95)s::VARCHAR), (%(id_m96)s::VARCHAR, %(name_m96)s::VARCHAR, %(meta_data_m96)s::JSONB,
#          %(filters_m96)s::JSONB, %(content_m96)s::VARCHAR, %(embedding_m96)s, %(usage_m96)s::JSONB,
#          %(content_hash_m96)s::VARCHAR, %(content_id_m96)s::VARCHAR), (%(id_m97)s::VARCHAR, %(name_m97)s::VARCHAR,
#          %(meta_data_m97)s::JSONB, %(filters_m97)s::JSONB, %(content_m97)s::VARCHAR, %(embedding_m97)s,
#          %(usage_m97)s::JSONB, %(content_hash_m97)s::VARCHAR, %(content_id_m97)s::VARCHAR), (%(id_m98)s::VARCHAR,
#          %(name_m98)s::VARCHAR, %(meta_data_m98)s::JSONB, %(filters_m98)s::JSONB, %(content_m98)s::VARCHAR,
#          %(embedding_m98)s, %(usage_m98)s::JSONB, %(content_hash_m98)s::VARCHAR, %(content_id_m98)s::VARCHAR),
#          (%(id_m99)s::VARCHAR, %(name_m99)s::VARCHAR, %(meta_data_m99)s::JSONB, %(filters_m99)s::JSONB,
#          %(content_m99)s::VARCHAR, %(embedding_m99)s, %(usage_m99)s::JSONB, %(content_hash_m99)s::VARCHAR,
#          %(content_id_m99)s::VARCHAR) ON CONFLICT (id) DO UPDATE SET name = excluded.name, meta_data =
#          excluded.meta_data, filters = excluded.filters, content = excluded.content, embedding =
#          excluded.embedding, usage = excluded.usage, content_hash = excluded.content_hash, content_id =
#          excluded.content_id]
#          [parameters: {'id_m0': '4860e32a0e009df461f695f59a2995e0', 'name_m0': None, 'meta_data_m0': Jsonb({'page':
#          400, 'chunk': 1, 'chunk_si ... (45 chars)), 'filters_m0': Jsonb(None), 'content_m0': '[CONTEXT: This chunk
#          outlines several specific quantitative criteria for stock selection, focusing on earnings stability,
#          dividend history, earnings  ... (2455 characters truncated) ...  low multiplier of current earnings and
#          below asset value, should offer good promise of satisfactory investment results. 386 The Intelligent
#          Investor', 'embedding_m0':
#          '[0.08244962245225906,0.003228485118597746,-0.009494980797171593,-0.006355016026645899,0.01862023212015628
#          8,0.031839266419410706,0.06256675720214844,- ... (15928 characters truncated) ...
#          ,0.0035117785446345806,0.006018238142132759,0.017831500619649887,-0.051242221146821976,-0.0391342639923095
#          7,0.05676865577697754,-0.04534910246729851]', 'usage_m0': Jsonb(None), 'content_hash_m0':
#          '4bf3723203cc1680c0e3b29222e92acbd69f9d21593a1bb576512afc8a1f5275', 'content_id_m0':
#          'bd502884-17e2-56a6-b869-8298c0c2afa8', 'id_m1': 'afd3683a5b8f9835cd7ba7023eb38b42', 'name_m1': None,
#          'meta_data_m1': Jsonb({'page': 401, 'chunk': 1, 'chunk_si ... (45 chars)), 'filters_m1': Jsonb(None),
#          'content_m1': '[CONTEXT: This chunk introduces the idea of simplifying stock selection by using a single,
#          plausible criterion. It questions whether simple metrics l ... (1772 characters truncated) ... 7 B+ 39 1⁄2
#          Binks Mfg. 15 1⁄4 1.83 14.41 B+ 21 1⁄2 Bluefield Supply 22 1⁄4 2.59 28.66 n.r. a 391⁄2 b a n.r. = not
#          ranked. b Adjusted for stock split.', 'embedding_m1':
#          '[0.04747982323169708,0.008621248416602612,-0.03555199131369591,0.021906889975070953,0.026690136641263962,
#          0.020369665697216988,0.07096382975578308,-0. ... (15908 characters truncated) ...
#          9,0.026176346465945244,-0.0068396031856536865,0.008640537969768047,-0.05165911465883255,-0.061674132943153
#          38,0.0519774965941906,-0.05329008772969246]', 'usage_m1': Jsonb(None), 'content_hash_m1':
#          '4bf3723203cc1680c0e3b29222e92acbd69f9d21593a1bb576512afc8a1f5275', 'content_id_m1':
#          'bd502884-17e2-56a6-b869-8298c0c2afa8', 'id_m2': 'd8ee0ddadc2470c8b6a074046970f21e', 'name_m2': None,
#          'meta_data_m2': Jsonb({'page': 402, 'chunk': 1, 'chunk_si ... (45 chars)), 'filters_m2': Jsonb(None),
#          'content_m2': '[CONTEXT: This chunk introduces the concept of "working-capital value" and contrasts its
#          historical performance with the "low-multiplier criterion" f ... (2482 characters truncated) ...  ensuing
#          price collapse, but also to delay their full recovery—in many cases indefinitely. The moral for the
#          intelligent 388 The Intelligent Investor', 'embedding_m2':
#          '[0.05715467780828476,0.013287440873682499,-0.040915314108133316,0.0009304286213591695,0.00412144185975194
#          ,0.055012624710798264,0.07591519504785538,-0 ... (15929 characters truncated) ...
#          ,0.022380108013749123,-0.008702271617949009,-0.02245107665657997,-0.04520101100206375,-0.06551700085401535
#          ,0.044176630675792694,-0.07486504316329956]', 'usage_m2': Jsonb(None), 'content_hash_m2':
#          '4bf3723203cc1680c0e3b29222e92acbd69f9d21593a1bb576512afc8a1f5275', 'content_id_m2':
#          'bd502884-17e2-56a6-b869-8298c0c2afa8', 'id_m3': '9ef0be932ccf98175b44b6cec21d6e4d', 'name_m3': None,
#          'meta_data_m3': Jsonb({'page': 403, 'chunk': 1, 'chunk_si ... (45 chars)), 'filters_m3': Jsonb(None),
#          'content_m3': '[CONTEXT: This chunk introduces the findings of portfolio studies, highlighting specific
#          investment groups that outperformed market indexes. It then  ... (2250 characters truncated) ... acquire
#          other companies for substantially more than the value of their assets, or its own stock can trade for
#          substantially more than its book value.', 'embedding_m3':
#          '[0.05501001328229904,0.018017930909991264,-0.025691915303468704,-0.006615650374442339,0.0321543850004673,
#          0.03401918336749077,0.04592283070087433,0.01 ... (15920 characters truncated) ...
#          6,0.04829340800642967,-0.006259717512875795,0.006088712252676487,-0.05404486879706383,-0.04477220401167869
#          6,0.06757529079914093,-0.08690804988145828]', 'usage_m3': Jsonb(None), 'content_hash_m3':
#          '4bf3723203cc1680c0e3b29222e92acbd69f9d21593a1bb576512afc8a1f5275', 'content_id_m3':
#          'bd502884-17e2-56a6-b869-8298c0c2afa8', 'id_m4': '135cbd73ad20b6aab4fd0f35accfadfb', 'name_m4': None,
#          'meta_data_m4': Jsonb({'page': 404, 'chunk': 1, 'chunk_si ... (45 chars)), 'filters_m4': Jsonb(None),
#          'content_m4': '[CONTEXT: This chunk discusses the concept of "market momentum" in relation to large,
#          established companies with strong track records. It explains ho ... (2399 characters truncated) ... e less
#          than their net-current-asset value. The rea- son was that only a handful, at most, of such issues would
#          have been 390 The Intelligent Investor', 'embedding_m4':
#          '[0.042240068316459656,0.012172570452094078,-0.007179140578955412,0.0029068603180348873,0.0380689315497875
#          2,0.022066105157136917,0.05553248152136803,0 ... (15900 characters truncated) ...
#          8,0.0390506386756897,0.008243921212852001,-0.0005010983441025019,-0.036169394850730896,-0.0465995371341705
#          3,0.07061182707548141,-0.06719594448804855]', 'usage_m4': Jsonb(None), 'content_hash_m4':
#          '4bf3723203cc1680c0e3b29222e92acbd69f9d21593a1bb576512afc8a1f5275', 'content_id_m4':
#          'bd502884-17e2-56a6-b869-8298c0c2afa8', 'id_m5': '2358848af19d5ff8aa57b53ba9eb6d05', 'name_m5': None,
#          'meta_data_m5': Jsonb({'page': 405, 'chunk': 1, 'chunk_si ... (45 chars)), 'filters_m5': Jsonb(None),
#          'content_m5': "[CONTEXT: This chunk discusses the author's investment strategy of buying stocks below
#          their net current asset value. It highlights how market declin ... (2020 characters truncated) ... r of
#          shares outstanding. Here, however, Graham means “ net working-capital value, ” or the per-share value of
#          current assets minus total liabilities." ... 800 parameters truncated ... 'content_m94': "[CONTEXT: This
#          chunk discusses the extreme undervaluation of 3Com's core businesses relative to its stake in Palm. It
#          highlights how the market's per ... (1196 characters truncated) ... he Market Add and Subtract?” National
#          Bureau of Eco- nomic Research working paper no. 8302, at www.nber.org/papers/w8302. Source:
#          www.morningstar.com", 'embedding_m94':
#          '[0.07998363673686981,0.03843246027827263,-0.04540345072746277,-0.014782650396227837,-0.006819776725023985
#          ,0.019128892570734024,0.04984638839960098,-0 ... (15946 characters truncated) ...
#          0.026898011565208435,-0.012838385067880154,-0.023476742208003998,-0.03905714303255081,-0.04107247665524483
#          ,0.04884451627731323,-0.051471978425979614]', 'usage_m94': Jsonb(None), 'content_hash_m94':
#          '4bf3723203cc1680c0e3b29222e92acbd69f9d21593a1bb576512afc8a1f5275', 'content_id_m94':
#          'bd502884-17e2-56a6-b869-8298c0c2afa8', 'id_m95': '433ecc5e75723d21052c0b10075260a9', 'name_m95': None,
#          'meta_data_m95': Jsonb({'page': 495, 'chunk': 1, 'chunk_si ... (45 chars)), 'filters_m95': Jsonb(None),
#          'content_m95': '[CONTEXT: This chunk introduces two companies, CMGI and CGI, and details CMGI\'s rapid
#          growth as an "Internet incubator" in the late 1990s through it ... (2221 characters truncated) ... courses
#          to academic publishers—a business that bore a faint but disturbing similarity to National Student Mar-
#          keting, discussed by Graham on p. 235.', 'embedding_m95':
#          '[0.03212587907910347,0.058048542588949203,-0.0166173093020916,0.023850217461586,0.0028635812923312187,0.0
#          57153746485710144,0.04600020870566368,0.0488 ... (15884 characters truncated) ...
#          526,0.043445296585559845,0.025661254301667213,0.018302153795957565,-0.055921074002981186,-0.08968462795019
#          15,0.06076860800385475,-0.0594371072947979]', 'usage_m95': Jsonb(None), 'content_hash_m95':
#          '4bf3723203cc1680c0e3b29222e92acbd69f9d21593a1bb576512afc8a1f5275', 'content_id_m95':
#          'bd502884-17e2-56a6-b869-8298c0c2afa8', 'id_m96': '55c51d3e8a8f322ea9a5bded0f5039f1', 'name_m96': None,
#          'meta_data_m96': Jsonb({'page': 496, 'chunk': 1, 'chunk_si ... (45 chars)), 'filters_m96': Jsonb(None),
#          'content_m96': "[CONTEXT: This chunk discusses the severe stock market losses experienced by CMGI, in
#          stark contrast to the steady performance of CGI. It highlights  ... (2319 characters truncated) ... n the
#          other hand, from 1992 through the end of 2001, Stryker’s earnings had risen 18.6% annually; its dividend
#          had grown 482 Commentary on Chapter 18", 'embedding_m96':
#          '[0.07990153133869171,0.02597835846245289,0.02388121373951435,-0.01041185762733221,0.012739376164972782,0.
#          03494333475828171,0.07917366176843643,0.0391 ... (15880 characters truncated) ...
#          0.036207713186740875,-0.013801774010062218,-0.0007752592791803181,-0.049722835421562195,-0.083157107234001
#          16,0.0760476142168045,-0.08302795141935349]', 'usage_m96': Jsonb(None), 'content_hash_m96':
#          '4bf3723203cc1680c0e3b29222e92acbd69f9d21593a1bb576512afc8a1f5275', 'content_id_m96':
#          'bd502884-17e2-56a6-b869-8298c0c2afa8', 'id_m97': 'a3805bf0946e21bc23385faaa366f549', 'name_m97': None,
#          'meta_data_m97': Jsonb({'page': 497, 'chunk': 1, 'chunk_si ... (45 chars)), 'filters_m97': Jsonb(None),
#          'content_m97': "[CONTEXT: This chunk discusses how market panic, exemplified by the WorldCom bankruptcy
#          and the subsequent stock market decline, caused the stock pri ... (2589 characters truncated) ... rom $21
#          million in net income on $1.1 billion in sales in 1997 . Nortek’s profit margin (net earnings as a
#          percentage of Commentary on Chapter 18 483", 'embedding_m97':
#          '[0.06908507645130157,0.013242737390100956,0.016766557469964027,0.009964759461581707,0.007421554997563362,
#          0.018820149824023247,0.10005947202444077,0.0 ... (15843 characters truncated) ...
#          134,0.03401251882314682,-0.0008743096841499209,-0.010694533586502075,-0.04622418433427811,-0.0959510207176
#          2085,0.050474863499403,-0.0746893659234047]', 'usage_m97': Jsonb(None), 'content_hash_m97':
#          '4bf3723203cc1680c0e3b29222e92acbd69f9d21593a1bb576512afc8a1f5275', 'content_id_m97':
#          'bd502884-17e2-56a6-b869-8298c0c2afa8', 'id_m98': '9d6ac4354a130d467b46fe08d47f3dd0', 'name_m98': None,
#          'meta_data_m98': Jsonb({'page': 498, 'chunk': 1, 'chunk_si ... (45 chars)), 'filters_m98': Jsonb(None),
#          'content_m98': "[CONTEXT: This chunk discusses the financial performance and stock valuation of two
#          companies, Nortek and Nortel. It highlights how Nortek improved i ... (2245 characters truncated) ... ham
#          had singled out Brown Shoe as one of the most stable companies on the New York Stock Exchange. See the
#          1934 edition of Security Analysis, p. 159.", 'embedding_m98':
#          '[0.028397804126143456,-0.008647891692817211,-0.0008886292343959212,0.01436565537005663,0.0104479128494858
#          74,0.06570765376091003,0.07102604955434799,0 ... (15875 characters truncated) ...
#          .048952072858810425,-0.013013151474297047,0.009433630853891373,-0.055501680821180344,-0.05710864067077637,
#          0.025002462789416313,-0.054673269391059875]', 'usage_m98': Jsonb(None), 'content_hash_m98':
#          '4bf3723203cc1680c0e3b29222e92acbd69f9d21593a1bb576512afc8a1f5275', 'content_id_m98':
#          'bd502884-17e2-56a6-b869-8298c0c2afa8', 'id_m99': 'c6f4efe889dbf79ba11e351ac07e1dfb', 'name_m99': None,
#          'meta_data_m99': Jsonb({'page': 499, 'chunk': 1, 'chunk_si ... (45 chars)), 'filters_m99': Jsonb(None),
#          'content_m99': '[CONTEXT: This chunk introduces the financial performance of Red Hat, highlighting its low
#          revenues and significant net loss. It then contrasts this  ... (1715 characters truncated) ... %) –4.6
#          28.2 49.5 Net earnings ($ millions) 36 36 –4 Note: Total returns for calendar year; net earnings for
#          fiscal year. Source: www.morningstar.com', 'embedding_m99':
#          '[0.03367910534143448,-0.008438046090304852,0.0017509934259578586,0.023076584562659264,0.02084803022444248
#          2,0.060354020446538925,0.020600972697138786, ... (15926 characters truncated) ...
#          ,0.05084735527634621,-0.020764252170920372,-0.002527693985030055,-0.06338153779506683,-0.03108124621212482
#          5,0.0410965271294117,-0.047763314098119736]', 'usage_m99': Jsonb(None), 'content_hash_m99':
#          '4bf3723203cc1680c0e3b29222e92acbd69f9d21593a1bb576512afc8a1f5275', 'content_id_m99':
#          'bd502884-17e2-56a6-b869-8298c0c2afa8'}]
#          (Background on this error at: https://sqlalche.me/e/20/f405)
# ERROR    Error upserting documents: (psycopg.errors.DuplicatePreparedStatement) prepared statement "_pg3_0" already
#          exists
#          [SQL: INSERT INTO ai.economics_enhanced_gemini (id, name, meta_data, filters, content, embedding, usage,
#          content_hash, content_id) VALUES (%(id_m0)s::VARCHAR, %(name_m0)s::VARCHAR, %(meta_data_m0)s::JSONB,
#          %(filters_m0)s::JSONB, %(content_m0)s::VARCHAR, %(embedding_m0)s, %(usage_m0)s::JSONB,
#          %(content_hash_m0)s::VARCHAR, %(content_id_m0)s::VARCHAR), (%(id_m1)s::VARCHAR, %(name_m1)s::VARCHAR,
#          %(meta_data_m1)s::JSONB, %(filters_m1)s::JSONB, %(content_m1)s::VARCHAR, %(embedding_m1)s,
#          %(usage_m1)s::JSONB, %(content_hash_m1)s::VARCHAR, %(content_id_m1)s::VARCHAR), (%(id_m2)s::VARCHAR,
#          %(name_m2)s::VARCHAR, %(meta_data_m2)s::JSONB, %(filters_m2)s::JSONB, %(content_m2)s::VARCHAR,
#          %(embedding_m2)s, %(usage_m2)s::JSONB, %(content_hash_m2)s::VARCHAR, %(content_id_m2)s::VARCHAR),
#          (%(id_m3)s::VARCHAR, %(name_m3)s::VARCHAR, %(meta_data_m3)s::JSONB, %(filters_m3)s::JSONB,
#          %(content_m3)s::VARCHAR, %(embedding_m3)s, %(usage_m3)s::JSONB, %(content_hash_m3)s::VARCHAR,
#          %(content_id_m3)s::VARCHAR), (%(id_m4)s::VARCHAR, %(name_m4)s::VARCHAR, %(meta_data_m4)s::JSONB,
#          %(filters_m4)s::JSONB, %(content_m4)s::VARCHAR, %(embedding_m4)s, %(usage_m4)s::JSONB,
#          %(content_hash_m4)s::VARCHAR, %(content_id_m4)s::VARCHAR), (%(id_m5)s::VARCHAR, %(name_m5)s::VARCHAR,
#          %(meta_data_m5)s::JSONB, %(filters_m5)s::JSONB, %(content_m5)s::VARCHAR, %(embedding_m5)s,
#          %(usage_m5)s::JSONB, %(content_hash_m5)s::VARCHAR, %(content_id_m5)s::VARCHAR), (%(id_m6)s::VARCHAR,
#          %(name_m6)s::VARCHAR, %(meta_data_m6)s::JSONB, %(filters_m6)s::JSONB, %(content_m6)s::VARCHAR,
#          %(embedding_m6)s, %(usage_m6)s::JSONB, %(content_hash_m6)s::VARCHAR, %(content_id_m6)s::VARCHAR),
#          (%(id_m7)s::VARCHAR, %(name_m7)s::VARCHAR, %(meta_data_m7)s::JSONB, %(filters_m7)s::JSONB,
#          %(content_m7)s::VARCHAR, %(embedding_m7)s, %(usage_m7)s::JSONB, %(content_hash_m7)s::VARCHAR,
#          %(content_id_m7)s::VARCHAR), (%(id_m8)s::VARCHAR, %(name_m8)s::VARCHAR, %(meta_data_m8)s::JSONB,
#          %(filters_m8)s::JSONB, %(content_m8)s::VARCHAR, %(embedding_m8)s, %(usage_m8)s::JSONB,
#          %(content_hash_m8)s::VARCHAR, %(content_id_m8)s::VARCHAR), (%(id_m9)s::VARCHAR, %(name_m9)s::VARCHAR,
#          %(meta_data_m9)s::JSONB, %(filters_m9)s::JSONB, %(content_m9)s::VARCHAR, %(embedding_m9)s,
#          %(usage_m9)s::JSONB, %(content_hash_m9)s::VARCHAR, %(content_id_m9)s::VARCHAR), (%(id_m10)s::VARCHAR,
#          %(name_m10)s::VARCHAR, %(meta_data_m10)s::JSONB, %(filters_m10)s::JSONB, %(content_m10)s::VARCHAR,
#          %(embedding_m10)s, %(usage_m10)s::JSONB, %(content_hash_m10)s::VARCHAR, %(content_id_m10)s::VARCHAR),
#          (%(id_m11)s::VARCHAR, %(name_m11)s::VARCHAR, %(meta_data_m11)s::JSONB, %(filters_m11)s::JSONB,
#          %(content_m11)s::VARCHAR, %(embedding_m11)s, %(usage_m11)s::JSONB, %(content_hash_m11)s::VARCHAR,
#          %(content_id_m11)s::VARCHAR), (%(id_m12)s::VARCHAR, %(name_m12)s::VARCHAR, %(meta_data_m12)s::JSONB,
#          %(filters_m12)s::JSONB, %(content_m12)s::VARCHAR, %(embedding_m12)s, %(usage_m12)s::JSONB,
#          %(content_hash_m12)s::VARCHAR, %(content_id_m12)s::VARCHAR), (%(id_m13)s::VARCHAR, %(name_m13)s::VARCHAR,
#          %(meta_data_m13)s::JSONB, %(filters_m13)s::JSONB, %(content_m13)s::VARCHAR, %(embedding_m13)s,
#          %(usage_m13)s::JSONB, %(content_hash_m13)s::VARCHAR, %(content_id_m13)s::VARCHAR), (%(id_m14)s::VARCHAR,
#          %(name_m14)s::VARCHAR, %(meta_data_m14)s::JSONB, %(filters_m14)s::JSONB, %(content_m14)s::VARCHAR,
#          %(embedding_m14)s, %(usage_m14)s::JSONB, %(content_hash_m14)s::VARCHAR, %(content_id_m14)s::VARCHAR),
#          (%(id_m15)s::VARCHAR, %(name_m15)s::VARCHAR, %(meta_data_m15)s::JSONB, %(filters_m15)s::JSONB,
#          %(content_m15)s::VARCHAR, %(embedding_m15)s, %(usage_m15)s::JSONB, %(content_hash_m15)s::VARCHAR,
#          %(content_id_m15)s::VARCHAR), (%(id_m16)s::VARCHAR, %(name_m16)s::VARCHAR, %(meta_data_m16)s::JSONB,
#          %(filters_m16)s::JSONB, %(content_m16)s::VARCHAR, %(embedding_m16)s, %(usage_m16)s::JSONB,
#          %(content_hash_m16)s::VARCHAR, %(content_id_m16)s::VARCHAR), (%(id_m17)s::VARCHAR, %(name_m17)s::VARCHAR,
#          %(meta_data_m17)s::JSONB, %(filters_m17)s::JSONB, %(content_m17)s::VARCHAR, %(embedding_m17)s,
#          %(usage_m17)s::JSONB, %(content_hash_m17)s::VARCHAR, %(content_id_m17)s::VARCHAR), (%(id_m18)s::VARCHAR,
#          %(name_m18)s::VARCHAR, %(meta_data_m18)s::JSONB, %(filters_m18)s::JSONB, %(content_m18)s::VARCHAR,
# ...
#          excluded.content_id]
#          [parameters: {'id_m0': '4860e32a0e009df461f695f59a2995e0', 'name_m0': None, 'meta_data_m0': Jsonb({'page':
#          400, 'chunk': 1, 'chunk_si ... (45 chars)), 'filters_m0': Jsonb(None), 'content_m0': '[CONTEXT: This chunk
#          outlines several specific quantitative criteria for stock selection, focusing on earnings stability,
#          dividend history, earnings  ... (2455 characters truncated) ...  low multiplier of current earnings and
#          below asset value, should offer good promise of satisfactory investment results. 386 The Intelligent
#          Investor', 'embedding_m0':
#          '[0.08244962245225906,0.003228485118597746,-0.009494980797171593,-0.006355016026645899,0.01862023212015628
#          8,0.031839266419410706,0.06256675720214844,- ... (15928 characters truncated) ...
#          ,0.0035117785446345806,0.006018238142132759,0.017831500619649887,-0.051242221146821976,-0.0391342639923095
#          7,0.05676865577697754,-0.04534910246729851]', 'usage_m0': Jsonb(None), 'content_hash_m0':
#          '4bf3723203cc1680c0e3b29222e92acbd69f9d21593a1bb576512afc8a1f5275', 'content_id_m0':
#          'bd502884-17e2-56a6-b869-8298c0c2afa8', 'id_m1': 'afd3683a5b8f9835cd7ba7023eb38b42', 'name_m1': None,
#          'meta_data_m1': Jsonb({'page': 401, 'chunk': 1, 'chunk_si ... (45 chars)), 'filters_m1': Jsonb(None),
#          'content_m1': '[CONTEXT: This chunk introduces the idea of simplifying stock selection by using a single,
#          plausible criterion. It questions whether simple metrics l ... (1772 characters truncated) ... 7 B+ 39 1⁄2
#          Binks Mfg. 15 1⁄4 1.83 14.41 B+ 21 1⁄2 Bluefield Supply 22 1⁄4 2.59 28.66 n.r. a 391⁄2 b a n.r. = not
#          ranked. b Adjusted for stock split.', 'embedding_m1':
#          '[0.04747982323169708,0.008621248416602612,-0.03555199131369591,0.021906889975070953,0.026690136641263962,
#          0.020369665697216988,0.07096382975578308,-0. ... (15908 characters truncated) ...
#          9,0.026176346465945244,-0.0068396031856536865,0.008640537969768047,-0.05165911465883255,-0.061674132943153
#          38,0.0519774965941906,-0.05329008772969246]', 'usage_m1': Jsonb(None), 'content_hash_m1':
#          '4bf3723203cc1680c0e3b29222e92acbd69f9d21593a1bb576512afc8a1f5275', 'content_id_m1':
#          'bd502884-17e2-56a6-b869-8298c0c2afa8', 'id_m2': 'd8ee0ddadc2470c8b6a074046970f21e', 'name_m2': None,
#          'meta_data_m2': Jsonb({'page': 402, 'chunk': 1, 'chunk_si ... (45 chars)), 'filters_m2': Jsonb(None),
#          'content_m2': '[CONTEXT: This chunk introduces the concept of "working-capital value" and contrasts its
#          historical performance with the "low-multiplier criterion" f ... (2482 characters truncated) ...  ensuing
#          price collapse, but also to delay their full recovery—in many cases indefinitely. The moral for the
#          intelligent 388 The Intelligent Investor', 'embedding_m2':
#          '[0.05715467780828476,0.013287440873682499,-0.040915314108133316,0.0009304286213591695,0.00412144185975194
#          ,0.055012624710798264,0.07591519504785538,-0 ... (15929 characters truncated) ...
#          ,0.022380108013749123,-0.008702271617949009,-0.02245107665657997,-0.04520101100206375,-0.06551700085401535
#          ,0.044176630675792694,-0.07486504316329956]', 'usage_m2': Jsonb(None), 'content_hash_m2':
#          '4bf3723203cc1680c0e3b29222e92acbd69f9d21593a1bb576512afc8a1f5275', 'content_id_m2':
#          'bd502884-17e2-56a6-b869-8298c0c2afa8', 'id_m3': '9ef0be932ccf98175b44b6cec21d6e4d', 'name_m3': None,
#          'meta_data_m3': Jsonb({'page': 403, 'chunk': 1, 'chunk_si ... (45 chars)), 'filters_m3': Jsonb(None),
#          'content_m3': '[CONTEXT: This chunk introduces the findings of portfolio studies, highlighting specific
#          investment groups that outperformed market indexes. It then  ... (2250 characters truncated) ... acquire
#          other companies for substantially more than the value of their assets, or its own stock can trade for
#          substantially more than its book value.', 'embedding_m3':
#          '[0.05501001328229904,0.018017930909991264,-0.025691915303468704,-0.006615650374442339,0.0321543850004673,
#          0.03401918336749077,0.04592283070087433,0.01 ... (15920 characters truncated) ...
#          6,0.04829340800642967,-0.006259717512875795,0.006088712252676487,-0.05404486879706383,-0.04477220401167869
#          6,0.06757529079914093,-0.08690804988145828]', 'usage_m3': Jsonb(None), 'content_hash_m3':
#          '4bf3723203cc1680c0e3b29222e92acbd69f9d21593a1bb576512afc8a1f5275', 'content_id_m3':
#          'bd502884-17e2-56a6-b869-8298c0c2afa8', 'id_m4': '135cbd73ad20b6aab4fd0f35accfadfb', 'name_m4': None,
#          'meta_data_m4': Jsonb({'page': 404, 'chunk': 1, 'chunk_si ... (45 chars)), 'filters_m4': Jsonb(None),
#          'content_m4': '[CONTEXT: This chunk discusses the concept of "market momentum" in relation to large,
#          established companies with strong track records. It explains ho ... (2399 characters truncated) ... e less
#          than their net-current-asset value. The rea- son was that only a handful, at most, of such issues would
#          have been 390 The Intelligent Investor', 'embedding_m4':
#          '[0.042240068316459656,0.012172570452094078,-0.007179140578955412,0.0029068603180348873,0.0380689315497875
#          2,0.022066105157136917,0.05553248152136803,0 ... (15900 characters truncated) ...
#          8,0.0390506386756897,0.008243921212852001,-0.0005010983441025019,-0.036169394850730896,-0.0465995371341705
#          3,0.07061182707548141,-0.06719594448804855]', 'usage_m4': Jsonb(None), 'content_hash_m4':
#          '4bf3723203cc1680c0e3b29222e92acbd69f9d21593a1bb576512afc8a1f5275', 'content_id_m4':
#          'bd502884-17e2-56a6-b869-8298c0c2afa8', 'id_m5': '2358848af19d5ff8aa57b53ba9eb6d05', 'name_m5': None,
#          'meta_data_m5': Jsonb({'page': 405, 'chunk': 1, 'chunk_si ... (45 chars)), 'filters_m5': Jsonb(None),
#          'content_m5': "[CONTEXT: This chunk discusses the author's investment strategy of buying stocks below
#          their net current asset value. It highlights how market declin ... (2020 characters truncated) ... r of
#          shares outstanding. Here, however, Graham means “ net working-capital value, ” or the per-share value of
#          current assets minus total liabilities." ... 800 parameters truncated ... 'content_m94': "[CONTEXT: This
#          chunk discusses the extreme undervaluation of 3Com's core businesses relative to its stake in Palm. It
#          highlights how the market's per ... (1196 characters truncated) ... he Market Add and Subtract?” National
#          Bureau of Eco- nomic Research working paper no. 8302, at www.nber.org/papers/w8302. Source:
#          www.morningstar.com", 'embedding_m94':
#          '[0.07998363673686981,0.03843246027827263,-0.04540345072746277,-0.014782650396227837,-0.006819776725023985
#          ,0.019128892570734024,0.04984638839960098,-0 ... (15946 characters truncated) ...
#          0.026898011565208435,-0.012838385067880154,-0.023476742208003998,-0.03905714303255081,-0.04107247665524483
#          ,0.04884451627731323,-0.051471978425979614]', 'usage_m94': Jsonb(None), 'content_hash_m94':
#          '4bf3723203cc1680c0e3b29222e92acbd69f9d21593a1bb576512afc8a1f5275', 'content_id_m94':
#          'bd502884-17e2-56a6-b869-8298c0c2afa8', 'id_m95': '433ecc5e75723d21052c0b10075260a9', 'name_m95': None,
#          'meta_data_m95': Jsonb({'page': 495, 'chunk': 1, 'chunk_si ... (45 chars)), 'filters_m95': Jsonb(None),
#          'content_m95': '[CONTEXT: This chunk introduces two companies, CMGI and CGI, and details CMGI\'s rapid
#          growth as an "Internet incubator" in the late 1990s through it ... (2221 characters truncated) ... courses
#          to academic publishers—a business that bore a faint but disturbing similarity to National Student Mar-
#          keting, discussed by Graham on p. 235.', 'embedding_m95':
#          '[0.03212587907910347,0.058048542588949203,-0.0166173093020916,0.023850217461586,0.0028635812923312187,0.0
#          57153746485710144,0.04600020870566368,0.0488 ... (15884 characters truncated) ...
#          526,0.043445296585559845,0.025661254301667213,0.018302153795957565,-0.055921074002981186,-0.08968462795019
#          15,0.06076860800385475,-0.0594371072947979]', 'usage_m95': Jsonb(None), 'content_hash_m95':
#          '4bf3723203cc1680c0e3b29222e92acbd69f9d21593a1bb576512afc8a1f5275', 'content_id_m95':
#          'bd502884-17e2-56a6-b869-8298c0c2afa8', 'id_m96': '55c51d3e8a8f322ea9a5bded0f5039f1', 'name_m96': None,
#          'meta_data_m96': Jsonb({'page': 496, 'chunk': 1, 'chunk_si ... (45 chars)), 'filters_m96': Jsonb(None),
#          'content_m96': "[CONTEXT: This chunk discusses the severe stock market losses experienced by CMGI, in
#          stark contrast to the steady performance of CGI. It highlights  ... (2319 characters truncated) ... n the
#          other hand, from 1992 through the end of 2001, Stryker’s earnings had risen 18.6% annually; its dividend
#          had grown 482 Commentary on Chapter 18", 'embedding_m96':
#          '[0.07990153133869171,0.02597835846245289,0.02388121373951435,-0.01041185762733221,0.012739376164972782,0.
#          03494333475828171,0.07917366176843643,0.0391 ... (15880 characters truncated) ...
#          0.036207713186740875,-0.013801774010062218,-0.0007752592791803181,-0.049722835421562195,-0.083157107234001
#          16,0.0760476142168045,-0.08302795141935349]', 'usage_m96': Jsonb(None), 'content_hash_m96':
#          '4bf3723203cc1680c0e3b29222e92acbd69f9d21593a1bb576512afc8a1f5275', 'content_id_m96':
#          'bd502884-17e2-56a6-b869-8298c0c2afa8', 'id_m97': 'a3805bf0946e21bc23385faaa366f549', 'name_m97': None,
#          'meta_data_m97': Jsonb({'page': 497, 'chunk': 1, 'chunk_si ... (45 chars)), 'filters_m97': Jsonb(None),
#          'content_m97': "[CONTEXT: This chunk discusses how market panic, exemplified by the WorldCom bankruptcy
#          and the subsequent stock market decline, caused the stock pri ... (2589 characters truncated) ... rom $21
#          million in net income on $1.1 billion in sales in 1997 . Nortek’s profit margin (net earnings as a
#          percentage of Commentary on Chapter 18 483", 'embedding_m97':
#          '[0.06908507645130157,0.013242737390100956,0.016766557469964027,0.009964759461581707,0.007421554997563362,
#          0.018820149824023247,0.10005947202444077,0.0 ... (15843 characters truncated) ...
#          134,0.03401251882314682,-0.0008743096841499209,-0.010694533586502075,-0.04622418433427811,-0.0959510207176
#          2085,0.050474863499403,-0.0746893659234047]', 'usage_m97': Jsonb(None), 'content_hash_m97':
#          '4bf3723203cc1680c0e3b29222e92acbd69f9d21593a1bb576512afc8a1f5275', 'content_id_m97':
#          'bd502884-17e2-56a6-b869-8298c0c2afa8', 'id_m98': '9d6ac4354a130d467b46fe08d47f3dd0', 'name_m98': None,
#          'meta_data_m98': Jsonb({'page': 498, 'chunk': 1, 'chunk_si ... (45 chars)), 'filters_m98': Jsonb(None),
#          'content_m98': "[CONTEXT: This chunk discusses the financial performance and stock valuation of two
#          companies, Nortek and Nortel. It highlights how Nortek improved i ... (2245 characters truncated) ... ham
#          had singled out Brown Shoe as one of the most stable companies on the New York Stock Exchange. See the
#          1934 edition of Security Analysis, p. 159.", 'embedding_m98':
#          '[0.028397804126143456,-0.008647891692817211,-0.0008886292343959212,0.01436565537005663,0.0104479128494858
#          74,0.06570765376091003,0.07102604955434799,0 ... (15875 characters truncated) ...
#          .048952072858810425,-0.013013151474297047,0.009433630853891373,-0.055501680821180344,-0.05710864067077637,
#          0.025002462789416313,-0.054673269391059875]', 'usage_m98': Jsonb(None), 'content_hash_m98':
#          '4bf3723203cc1680c0e3b29222e92acbd69f9d21593a1bb576512afc8a1f5275', 'content_id_m98':
#          'bd502884-17e2-56a6-b869-8298c0c2afa8', 'id_m99': 'c6f4efe889dbf79ba11e351ac07e1dfb', 'name_m99': None,
#          'meta_data_m99': Jsonb({'page': 499, 'chunk': 1, 'chunk_si ... (45 chars)), 'filters_m99': Jsonb(None),
#          'content_m99': '[CONTEXT: This chunk introduces the financial performance of Red Hat, highlighting its low
#          revenues and significant net loss. It then contrasts this  ... (1715 characters truncated) ... %) –4.6
#          28.2 49.5 Net earnings ($ millions) 36 36 –4 Note: Total returns for calendar year; net earnings for
#          fiscal year. Source: www.morningstar.com', 'embedding_m99':
#          '[0.03367910534143448,-0.008438046090304852,0.0017509934259578586,0.023076584562659264,0.02084803022444248
#          2,0.060354020446538925,0.020600972697138786, ... (15926 characters truncated) ...
#          ,0.05084735527634621,-0.020764252170920372,-0.002527693985030055,-0.06338153779506683,-0.03108124621212482
#          5,0.0410965271294117,-0.047763314098119736]', 'usage_m99': Jsonb(None), 'content_hash_m99':
#          '4bf3723203cc1680c0e3b29222e92acbd69f9d21593a1bb576512afc8a1f5275', 'content_id_m99':
#          'bd502884-17e2-56a6-b869-8298c0c2afa8'}]
#          (Background on this error at: https://sqlalche.me/e/20/f405)
# INFO Adding content from path, 2dcb0ad3-d197-58ee-919b-4b93a988e337, None,
#      /home/vitor/contextual-rag-agno-supabase/data/pdfs/The Essays of Warren Buffett_ Lessons for Corporate
#      America.pdf, None
# INFO Processing batch starting at index 0, size: 100
# INFO Upserted batch of 100 documents.
# INFO Processing batch starting at index 100, size: 100
# INFO Upserted batch of 100 documents.
# INFO Processing batch starting at index 200, size: 100
# INFO Upserted batch of 100 documents.
# INFO Processing batch starting at index 300, size: 23
# INFO Upserted batch of 23 documents.
# INFO Adding content from path, 9d419965-9199-596f-a187-fa39c9228b23, None,
#      /home/vitor/contextual-rag-agno-supabase/data/pdfs/Rich Dad Poor Dad.pdf, None
# Multiple definitions in dictionary at byte 0x7c8e5 for key /PageMode
# INFO Processing batch starting at index 0, size: 100
# INFO Upserted batch of 100 documents.
# INFO Processing batch starting at index 100, size: 20
# INFO Upserted batch of 20 documents.
# ✅ All PDFs ingested

# %% [markdown]
# ## 4. Compare: Regular vs Enhanced Chunks
#
# Enhanced chunks have `[CONTEXT: ...]` prefix explaining their role in the document.

# %%
results = kb.search("Explique de forma resumida e concisa o que é a quinta regra de ouro", limit=2)

print("Enhanced Chunks with Context:\n" + "="*80)
for i, result in enumerate(results, 1):
    print(f"\nResult {i}:")
    print(result.content[:500])
    print("-"*80)
# Out:
# INFO Found 2 documents
# Enhanced Chunks with Context:
# ================================================================================
#
# Result 1:
# [CONTEXT: This chunk introduces the "Five Laws of Gold," which are presented as fundamental principles for accumulating and managing wealth. The first law specifically discusses the importance of saving a portion of one's earnings to build a future financial fund.]
#
# AS CINCO LEIS DE OURO I. O ouro vem de bom grado e numa quantidade crescente para todo homem que separa não menos de um décimo de seus ganhos, a fim de criar um fundo para o seu futuro e o de sua própria família. II.0 ouro trabalha d
# --------------------------------------------------------------------------------
#
# Result 2:
# [CONTEXT: This chunk discusses the Fifth Law of Gold, which warns against investing money based on unrealistic promises, deceptive advice, or personal inexperience. It emphasizes that true wealth comes from prudent financial decisions guided by wisdom rather than wishful thinking.]
#
# que investe o seu dinheiro de acordo com o conselho dos homens acostumados a lidar com finanças." A Quinta Lei de Ouro O ouro escapa ao homem que o força a ganhos impossíveis ou que dá ouvidos aos conselhos enganosos
# --------------------------------------------------------------------------------

# %% [markdown]
# ## 5. Query with Agent

# %%
from agno.agent import Agent
from agno.models.google import Gemini
from src.config import settings

agent = Agent(
    model=Gemini(id="gemini-2.5-flash", api_key=settings.google_api_key),
    knowledge=kb.knowledge,
    search_knowledge=True,
    markdown=True,
    # debug_mode=True,
)

agent.print_response(
    "Explique de forma resumida e concisa o que é a quinta regra de ouro",
    stream=True
)
# Out:
# DEBUG ***** Session ID: a03b300d-3ee4-4c01-8551-17f6ba503945 *****
# DEBUG ***** Session ID: a03b300d-3ee4-4c01-8551-17f6ba503945 *****
# Output()
# INFO Found 10 documents
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ## 6. Accuracy Comparison
#
# Test the same query against different approaches:

# %%
from src.storage.agno_knowledge import AgnoKnowledge

kb_regular = AgnoKnowledge(table_name="economics_docs_gemini")
kb_enhanced = ContextualAgnoKnowledge(table_name="economics_enhanced_gemini")

query = "Explique de forma resumida e concisa o que é a quinta regra de ouro"

print("REGULAR SEMANTIC CHUNKING:")
print("="*80)
results_regular = kb_regular.search(query, limit=1)
print(results_regular[0].content[:600] if results_regular else "No results")

print("\n\nENHANCED CONTEXTUAL SEMANTIC CHUNKING:")
print("="*80)
results_enhanced = kb_enhanced.search(query, limit=1)
print(results_enhanced[0].content[:600] if results_enhanced else "No results")
# Out:
# REGULAR SEMANTIC CHUNKING:
# ================================================================================
# INFO Found 1 documents
# AS CINCO LEIS DE OURO I. O ouro vem de bom grado e numa quantidade crescente para todo homem que separa não menos de um décimo de seus ganhos, a fim de criar um fundo para o seu futuro e o de sua própria família. II.0 ouro trabalha diligente e satisfatoriamente para o homem prudente que, possuindo-o, encontra para ele um emprego lucrativo, multiplicando- o como os flocos de algodão no campo. III. O ouro busca a proteção do proprietário cauteloso que o investe de acordo com os conselhos de homens mais experimentados em seu manuseio. IV. O ouro foge do homem que o emprega em negócios ou propósit
#
#
# ENHANCED CONTEXTUAL SEMANTIC CHUNKING:
# ================================================================================
# INFO Found 1 documents
# [CONTEXT: This chunk introduces the "Five Laws of Gold," which are presented as fundamental principles for accumulating and managing wealth. The first law specifically discusses the importance of saving a portion of one's earnings to build a future financial fund.]
#
# AS CINCO LEIS DE OURO I. O ouro vem de bom grado e numa quantidade crescente para todo homem que separa não menos de um décimo de seus ganhos, a fim de criar um fundo para o seu futuro e o de sua própria família. II.0 ouro trabalha diligente e satisfatoriamente para o homem prudente que, possuindo-o, encontra para ele um emprego lu

# %% [markdown]
# ## 7. Multi-Document Queries

# %%
queries = [
    "What are the key principles of economics?",
    "How do markets self-regulate?",
    "What is the relationship between labor and value?"
]

for query in queries:
    print(f"\n{'='*80}")
    print(f"Q: {query}")
    print('='*80)
    agent.print_response(query, stream=True)
    print("\n")
