# %% [markdown]
# # Enhanced Contextual Semantic Chunking Demo
#
# **Best of both worlds:**
# 1. Semantic chunking (natural boundaries)
# 2. LLM contextual enhancement (situating context)
# 3. Hybrid search (vector + FTS)
#
# **Best for**: Production systems, 20-30% better retrieval accuracy

# %% [markdown]
# ## Setup

# %%
import subprocess
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))
pdf_dir = project_root / "data" / "pdfs"

print(f"✅ Project root: {project_root}")
# Out:
# ✅ Project root: /home/vitor/contextual-rag-agno-supabase

# %% [markdown]
# ## 1. Download Sample PDFs

# %%
# if pdf_dir.exists() and list(pdf_dir.glob("*.pdf")):
#     print(f"✅ PDFs already downloaded: {len(list(pdf_dir.glob('*.pdf')))} files")
# else:
#     print("📥 Downloading sample PDFs...")
#     result = subprocess.run([sys.executable, str(project_root / "scripts" / "download_pdfs.py")], 
#                           capture_output=True, text=True, cwd=str(project_root))
#     print(result.stdout)

# %% [markdown]
# ## 2. Initialize Enhanced Knowledge Base

# %%
from src.storage.enhanced_agno_knowledge import EnhancedAgnoKnowledge

kb = EnhancedAgnoKnowledge(table_name="economics_enhanced")
print("✅ Enhanced knowledge base initialized")
print("   - Semantic chunking: ON")
print("   - Contextual enhancement: ON")
print("   - Hybrid search: ON")
print(f"   - Table: {kb.knowledge.vector_db.table_name}")
# Out:
# ✅ Enhanced knowledge base initialized
#    - Semantic chunking: ON
#    - Contextual enhancement: ON
#    - Hybrid search: ON
#    - Table: economics_enhanced

# %% [markdown]
# ## 3. Ingest PDF with Context Enhancement
#
# This will:
# 1. Extract text from PDF
# 2. Chunk semantically (natural boundaries)
# 3. Add LLM-generated context to each chunk
# 4. Store with hybrid indexing

# %%
pdf_path = pdf_dir / "O-Homem-Mais-Rico-da-Babilonia-George-S.-Clason.pdf"
kb.ingest_pdf(str(pdf_path))
print("\n✅ PDF ingested with contextual enhancement")
# Out:
# 📄 Ingesting with context-enhanced semantic chunking: /home/vitor/contextual-rag-agno-supabase/data/pdfs/O-Homem-Mais-Rico-da-Babilonia-George-S.-Clason.pdf
# INFO Adding content from path, 944a1797-17db-5bbc-846b-481e3d7185ac, None,
#      /home/vitor/contextual-rag-agno-supabase/data/pdfs/O-Homem-Mais-Rico-da-Babilonia-George-S.-Clason.pdf, None
# Warning: Context generation failed: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\nPlease retry in 31.754221536s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '31s'}]}}
# Warning: Context generation failed: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\nPlease retry in 31.091349984s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '31s'}]}}
# Warning: Context generation failed: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\nPlease retry in 27.05479419s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '27s'}]}}
# Warning: Context generation failed: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\nPlease retry in 26.105248065s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '26s'}]}}
# Warning: Context generation failed: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\nPlease retry in 25.431143812s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '25s'}]}}
# Warning: Context generation failed: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\nPlease retry in 24.772527011s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '24s'}]}}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 pdf_path = pdf_dir / "O-Homem-Mais-Rico-da-Babilonia-George-S.-Clason.pdf"
# ----> 2 kb.ingest_pdf(str(pdf_path))
#       3 print("\n✅ PDF ingested with contextual enhancement")
#
# File ~/contextual-rag-agno-supabase/src/storage/enhanced_agno_knowledge.py:49, in EnhancedAgnoKnowledge.ingest_pdf(self, path)
#      47 """Ingest PDF with contextual semantic chunking."""
#      48 print(f"📄 Ingesting with context-enhanced semantic chunking: {path}")
# ---> 49 self.knowledge.insert(path=path, reader=self.pdf_reader)
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/agno/knowledge/knowledge.py:158, in Knowledge.insert(self, name, description, path, url, text_content, metadata, topics, remote_content, reader, include, exclude, upsert, skip_if_exists, auth)
#     155 content.content_hash = self._build_content_hash(content)
#     156 content.id = generate_id(content.content_hash)
# --> 158 self._load_content(content, upsert, skip_if_exists, include, exclude)
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/agno/knowledge/knowledge.py:1045, in Knowledge._load_content(self, content, upsert, skip_if_exists, include, exclude)
#    1043 """Synchronously load content."""
#    1044 if content.path:
# -> 1045     self._load_from_path(content, upsert, skip_if_exists, include, exclude)
#    1047 if content.url:
#    1048     self._load_from_url(content, upsert, skip_if_exists)
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/agno/knowledge/knowledge.py:1404, in Knowledge._load_from_path(self, content, upsert, skip_if_exists, include, exclude)
#    1402 if reader:
#    1403     password = content.auth.password if content.auth and content.auth.password is not None else None
# -> 1404     read_documents = self._read(reader, path, name=content.name or path.name, password=password)
#    1405 else:
#    1406     read_documents = []
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/agno/knowledge/knowledge.py:1199, in Knowledge._read(self, reader, source, name, password)
#    1197     return reader.read(source, name=name)
#    1198 else:
# -> 1199     return reader.read(source, name=name)
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/agno/knowledge/reader/pdf_reader.py:364, in PDFReader.read(self, pdf, name, password)
#     361     return []
#     363 # Read and chunk
# --> 364 return self._pdf_reader_to_documents(pdf_reader, doc_name, use_uuid_for_id=True)
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/agno/knowledge/reader/pdf_reader.py:300, in BasePDFReader._pdf_reader_to_documents(self, doc_reader, doc_name, read_images, use_uuid_for_id)
#     292         pdf_images_text.append(_ocr_reader(page))
#     294 pdf_content, shift = _clean_page_numbers(
#     295     page_content_list=pdf_content,
#     296     extra_content=pdf_images_text,
#     297     page_start_numbering_format=self.page_start_numbering_format,
#     298     page_end_numbering_format=self.page_end_numbering_format,
#     299 )
# --> 300 return self._create_documents(pdf_content, doc_name, use_uuid_for_id, shift)
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/agno/knowledge/reader/pdf_reader.py:277, in BasePDFReader._create_documents(self, pdf_content, doc_name, use_uuid_for_id, page_number_shift)
#     274     documents = [document]
#     276 if self.chunk:
# --> 277     return self._build_chunked_documents(documents)
#     278 return documents
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/agno/knowledge/reader/pdf_reader.py:217, in BasePDFReader._build_chunked_documents(self, documents)
#     215 chunked_documents: List[Document] = []
#     216 for document in documents:
# --> 217     chunked_documents.extend(self.chunk_document(document))
#     218 return chunked_documents
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/agno/knowledge/reader/base.py:76, in Reader.chunk_document(self, document)
#      74 if self.chunking_strategy is None:
#      75     self.chunking_strategy = FixedSizeChunking(chunk_size=self.chunk_size)
# ---> 76 return self.chunking_strategy.chunk(document)
#
# File ~/contextual-rag-agno-supabase/src/ingestion/contextual_semantic_chunking.py:53, in ContextualSemanticChunking.chunk(self, document)
#      47 try:
#      48     prompt = self.CONTEXT_PROMPT.format(
#      49         whole_doc=doc_preview,
#      50         chunk_content=chunk.content[:500]
#      51     )
# ---> 53     response = self.client.models.generate_content(
#      54         model=self.model_id,
#      55         contents=prompt
#      56     )
#      57     context_prefix = response.text
#      58     enhanced_content = f"[CONTEXT: {context_prefix.strip()}]\n\n{chunk.content}"
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/google/genai/models.py:5227, in Models.generate_content(self, model, contents, config)
#    5225 while remaining_remote_calls_afc > 0:
#    5226   i += 1
# -> 5227   response = self._generate_content(
#    5228       model=model, contents=contents, config=parsed_config
#    5229   )
#    5231   function_map = _extra_utils.get_function_map(parsed_config)
#    5232   if not function_map:
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/google/genai/models.py:4009, in Models._generate_content(self, model, contents, config)
#    4006 request_dict = _common.convert_to_dict(request_dict)
#    4007 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4009 response = self._api_client.request(
#    4010     'post', path, request_dict, http_options
#    4011 )
#    4013 if config is not None and getattr(
#    4014     config, 'should_return_http_response', None
#    4015 ):
#    4016   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/google/genai/_api_client.py:1386, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1376 def request(
#    1377     self,
#    1378     http_method: str,
#    (...)   1381     http_options: Optional[HttpOptionsOrDict] = None,
#    1382 ) -> SdkHttpResponse:
#    1383   http_request = self._build_request(
#    1384       http_method, path, request_dict, http_options
#    1385   )
# -> 1386   response = self._request(http_request, http_options, stream=False)
#    1387   response_body = (
#    1388       response.response_stream[0] if response.response_stream else ''
#    1389   )
#    1390   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/google/genai/_api_client.py:1222, in BaseApiClient._request(self, http_request, http_options, stream)
#    1219     retry = tenacity.Retrying(**retry_kwargs)
#    1220     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1222 return self._retry(self._request_once, http_request, stream)
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/tenacity/__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/tenacity/__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/tenacity/__init__.py:400, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     398 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     399     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 400         self._add_action_func(lambda rs: rs.outcome.result())
#     401         return
#     403     if self.after is not None:
#
# File ~/.pyenv/versions/3.13.3/lib/python3.13/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/.pyenv/versions/3.13.3/lib/python3.13/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/tenacity/__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/google/genai/_api_client.py:1192, in BaseApiClient._request_once(self, http_request, stream)
#    1188   return HttpResponse(
#    1189       response.headers, response if stream else [response.text]
#    1190   )
#    1191 else:
# -> 1192   response = self._httpx_client.request(
#    1193       method=http_request.method,
#    1194       url=http_request.url,
#    1195       headers=http_request.headers,
#    1196       content=data,
#    1197       timeout=http_request.timeout,
#    1198   )
#    1199   errors.APIError.raise_for_response(response)
#    1200   return HttpResponse(
#    1201       response.headers, response if stream else [response.text]
#    1202   )
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/httpx/_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/contextual-rag-agno-supabase/.venv/lib/python3.13/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~/.pyenv/versions/3.13.3/lib/python3.13/ssl.py:1285, in SSLSocket.recv(self, buflen, flags)
#    1281     if flags != 0:
#    1282         raise ValueError(
#    1283             "non-zero flags not allowed in calls to recv() on %s" %
#    1284             self.__class__)
# -> 1285     return self.read(buflen)
#    1286 else:
#    1287     return super().recv(buflen, flags)
#
# File ~/.pyenv/versions/3.13.3/lib/python3.13/ssl.py:1140, in SSLSocket.read(self, len, buffer)
#    1138         return self._sslobj.read(len, buffer)
#    1139     else:
# -> 1140         return self._sslobj.read(len)
#    1141 except SSLError as x:
#    1142     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %% [markdown]
# ## 4. Compare: Regular vs Enhanced Chunks
#
# Enhanced chunks have `[CONTEXT: ...]` prefix explaining their role in the document.

# %%
results = kb.search("What are the principles of wealth?", limit=2)

print("Enhanced Chunks with Context:\n" + "="*80)
for i, result in enumerate(results, 1):
    print(f"\nResult {i}:")
    print(result.content[:500])
    print("-"*80)

# %% [markdown]
# ## 5. Query with Agent

# %%
from agno.agent import Agent
from agno.models.google import Gemini

agent = Agent(
    model=Gemini(id="gemini-2.5-flash"),
    knowledge=kb.knowledge,
    search_knowledge=True,
    show_tool_calls=True,
    markdown=True
)

agent.print_response(
    "Explain the division of labor and its economic benefits",
    stream=True
)

# %% [markdown]
# ## 6. Accuracy Comparison
#
# Test the same query against different approaches:

# %%
from src.storage.agno_knowledge import AgnoKnowledge

kb_regular = AgnoKnowledge(table_name="economics_docs")
kb_enhanced = EnhancedAgnoKnowledge(table_name="economics_enhanced")

query = "How does specialization improve productivity?"

print("REGULAR SEMANTIC CHUNKING:")
print("="*80)
results_regular = kb_regular.search(query, limit=1)
print(results_regular[0].content[:400] if results_regular else "No results")

print("\n\nENHANCED CONTEXTUAL SEMANTIC CHUNKING:")
print("="*80)
results_enhanced = kb_enhanced.search(query, limit=1)
print(results_enhanced[0].content[:400] if results_enhanced else "No results")

# %% [markdown]
# ## 7. Multi-Document Queries

# %%
queries = [
    "What are the key principles of economics?",
    "How do markets self-regulate?",
    "What is the relationship between labor and value?"
]

for query in queries:
    print(f"\n{'='*80}")
    print(f"Q: {query}")
    print('='*80)
    agent.print_response(query, stream=True)
    print("\n")
